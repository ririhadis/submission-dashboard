# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Srie Wahyudhanis Hadis, S.Kom
# - **Email:** sriewahyudhanis.hadis@gmail.com
# - **ID Dicoding:** sriewahyudhanis.hadis@gmail.com

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Faktor apakah yang membuat penyewaan sepeda paling besar?
# - Pada pukul berapa dan kondisi bagaimana penyewaan sering terjadi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Memanggil data day.csv

# %%
day_df = pd.read_csv("data/day.csv")
day_df.head(5)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# #### Memanggil data hour.csv

# %%
hour_df = pd.read_csv("data/hour.csv")
hour_df.head(5)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Data pada tabel day_df terdiri dari data peminjaman dalam satu hari yang didapat dari banyaknya transaksi peminjaman pada hari itu, hal ini dapat terlihat pada entitas cnt, yang merangkum peminjaman pada tanggal tersebut
# - Data pada tabel hour_df terdiri dari peminjaman yang berdasarkan pada waktu dalam satu hari. Dapat dilihat dari peminjaman pada jam 1 pada tanggal 1 bulan 1 tahun 2011 terjadi peminjaman sebanyak 40 kali

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Melihat tipe data tabel day_df

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# #### Melihat missing value tabel day_df

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# #### Memeriksa duplikasi data pada tabel day_df

# %%
print("Jumlah duplikasi data pada tabel: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada tabel:  0

# %% [markdown]
# #### Memeriksa parameter statistik numerik tabel day_df

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.465233    0.544894    0.183051    0.162961    0.142429    0.077498
# min      0.000000    1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      0.000000    1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      1.000000    2.000000    0.655417    0.608602    0.730209    0.233214
# max      1.000000    3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %% [markdown]
# #### Melihat tipe data tabel hour_df

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# #### Melihat missing value tabel hour_df

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# #### Memeriksa duplikasi data tabel hour_df

# %%
print("Jumlah duplikasi data pada tabel :", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada tabel : 0

# %% [markdown]
# #### Memeriksa parameter statistik numerik tabel hour_df

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# **Insight:**
# - Setelah melakukan assesing data pada tabel day_df, tidak ditemukan duplikasi data ataupun data yang hilang, tetapi dapat dilihat bahwa tipe data pada  entitas dteday tidak sesuai karena menggunakan tipe data objek. Sedangkan pada statistik numerik tidak terlihat data yang berada diluar outliernya. Dapat disimpulkan data yang sudah ada pada tabel day_df 90% bersih dan dapat digunakan
# - Data pada tabel day_df pada kolom season, weathershit, year, holiday, workingday dan weekday berbentuk numerik dan perlu pengartian selanjutnya
# - Setelah melakukan assesing data pada tabel hour_df, juga tidak ditemukan duplikasi data dan juga data yang hilang, tetapi tipe data untuk entitas dteday tidak sesuai karena seharusnya bertipe data datetime. Sedangkan pada statistik numerik tidak ditemukan data yang berada di luar outlier. Seperti pada tabel day_df, dapat disimpulkan data hour_df 90% bersih dan dapat digunakan
# - begitu juga data pada tabel hour_df pada kolom season, weathershit, year, holiday, workingday dan weekday berbentuk numerik dan perlu pengartian selanjutnya

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Mengubah tipe data yang salah pada tabel day_df

# %%
datetime_column = ["dteday"]

for column in datetime_column:
    day_df[column] = pd.to_datetime(day_df[column])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
day_df.head(5)
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0        6           0
# 1        2 2011-01-02       1   0     1        0        0           0
# 2        3 2011-01-03       1   0     1        0        1           1
# 3        4 2011-01-04       1   0     1        0        2           1
# 4        5 2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# #### Mengubah tipe data dteday pada tabel hour_df

# %%
datetime_column = ["dteday"]

for column in datetime_column:
    hour_df[column] = pd.to_datetime(hour_df[column])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
hour_df.head(5)
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Bagian cleaning data pada tabel day_df hanya melakukan perubahan tipe data yang sesuai pada entitas dteday
# - Seperti halnya clening data pada tabel hour_df hanya melakukan perubahan tipe data yang sesuai dengan entitas dteday

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore tabel day_df

# %% [markdown]
# #### melihat statistik keseluruhan tabel day_df

# %%
day_df.describe(include="all")
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# min      0.000000    0.000000    0.000000    1.000000    0.059130    0.079070
# 25%      0.000000    1.000000    0.000000    1.000000    0.337083    0.337842
# 50%      0.000000    3.000000    1.000000    1.000000    0.498333    0.486733
# 75%      0.000000    5.000000    1.000000    2.000000    0.655417    0.608602
# max      1.000000    6.000000    1.000000    3.000000    0.861667    0.840896
# std      0.167155    2.004787    0.465233    0.544894    0.183051    0.162961
#
#               hum   windspeed       casual   registered          cnt
# count  731.000000  731.000000   731.000000   731.000000   731.000000
# mean     0.627894    0.190486   848.176471  3656.172367  4504.348837
# min      0.000000    0.022392     2.000000    20.000000    22.000000
# 25%      0.520000    0.134950   315.500000  2497.000000  3152.000000
# 50%      0.626667    0.180975   713.000000  3662.000000  4548.000000
# 75%      0.730209    0.233214  1096.000000  4776.500000  5956.000000
# max      0.972500    0.507463  3410.000000  6946.000000  8714.000000
# std      0.142429    0.077498   686.622488  1560.256377  1937.211452

# %% [markdown]
# #### Mengganti label numerik pada musim

# %%
day_df["season"]= day_df.season.apply(lambda x: "springer" if x == 1 else ("summer" if x == 2 else ("fall" if x == 3 else "winter")))
day_df.head(5)
# Out:
#    instant     dteday    season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01  springer   0     1        0        6           0
# 1        2 2011-01-02  springer   0     1        0        0           0
# 2        3 2011-01-03  springer   0     1        0        1           1
# 3        4 2011-01-04  springer   0     1        0        2           1
# 4        5 2011-01-05  springer   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# #### melihat jumlah penyewaan sepeda berdasarkan season

# %%
day_df.groupby(by="season").cnt.sum()
# Out:
# season
# fall        1061129
# springer     471348
# summer       918589
# winter       841613
# Name: cnt, dtype: int64

# %% [markdown]
# #### mengubah data weekday menggunakan label

# %%
day_df["weekday"]= day_df.weekday.apply(lambda x: "sunday" if x == 0 else ("monday" if x == 1 else ("tuesday" if x == 2 else ("wednesday" if x == 3 else ("thursday" if x == 4 else("friday" if x ==5 else "saturday"))))))
day_df.head(5)
# Out:
#    instant     dteday    season  yr  mnth  holiday    weekday  workingday  \
# 0        1 2011-01-01  springer   0     1        0   saturday           0
# 1        2 2011-01-02  springer   0     1        0     sunday           0
# 2        3 2011-01-03  springer   0     1        0     monday           1
# 3        4 2011-01-04  springer   0     1        0    tuesday           1
# 4        5 2011-01-05  springer   0     1        0  wednesday           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# #### melihat jumlah penyewaan berdasarkan hari kerja

# %%
day_df.groupby(by = "weekday").cnt.sum().sort_values(ascending=False)
# Out:
# weekday
# friday       487790
# thursday     485395
# saturday     477807
# wednesday    473048
# tuesday      469109
# monday       455503
# sunday       444027
# Name: cnt, dtype: int64

# %% [markdown]
# #### memberikan label pada cuaca

# %%
day_df["weathersit"]= day_df.weathersit.apply(lambda x: "clear, few clouds, partly cloudy" if x == 1 else ("mist + cloudy, mist + broken, mist + few clouds" if x == 2 else ("light snow, light rain + thunderstorm + scatter clouds, light rain + scatter clouds" if x == 3 else "heavy rain + ice pallets + thunderstorm + mist, snow + fog")))
day_df.head(5)
# Out:
#    instant     dteday    season  yr  mnth  holiday    weekday  workingday  \
# 0        1 2011-01-01  springer   0     1        0   saturday           0
# 1        2 2011-01-02  springer   0     1        0     sunday           0
# 2        3 2011-01-03  springer   0     1        0     monday           1
# 3        4 2011-01-04  springer   0     1        0    tuesday           1
# 4        5 2011-01-05  springer   0     1        0  wednesday           1
#
#                                         weathersit      temp     atemp  \
# 0  mist + cloudy, mist + broken, mist + few clouds  0.344167  0.363625
# 1  mist + cloudy, mist + broken, mist + few clouds  0.363478  0.353739
# 2                 clear, few clouds, partly cloudy  0.196364  0.189405
# 3                 clear, few clouds, partly cloudy  0.200000  0.212122
# 4                 clear, few clouds, partly cloudy  0.226957  0.229270
#
#         hum  windspeed  casual  registered   cnt
# 0  0.805833   0.160446     331         654   985
# 1  0.696087   0.248539     131         670   801
# 2  0.437273   0.248309     120        1229  1349
# 3  0.590435   0.160296     108        1454  1562
# 4  0.436957   0.186900      82        1518  1600

# %% [markdown]
# #### memberikan label pada tahun

# %%
day_df["yr"]= day_df.yr.apply(lambda x: 2011 if x == 0 else 2012)
day_df.sample()
# Out:
#      instant     dteday season    yr  mnth  holiday weekday  workingday  \
# 183      184 2011-07-03   fall  2011     7        0  sunday           0
#
#                                           weathersit      temp     atemp  \
# 183  mist + cloudy, mist + broken, mist + few clouds  0.716667  0.668575
#
#         hum  windspeed  casual  registered   cnt
# 183  0.6825   0.228858    2282        2367  4649

# %% [markdown]
# #### melihat penyewaan sepeda yang terjadi bedasarkan kelompk musim dan tahun

# %%
day_df.groupby(by = ["season", "yr"]).agg({
    "casual" : "sum",
    "registered" : "sum",
    "cnt" : ["max", "min", "mean"]
})
# Out:
#                casual registered   cnt
#                   sum        sum   max   min         mean
# season   yr
# fall     2011   95450     324200  6043  1115  4464.361702
#          2012  130641     510838  8714  4073  6824.244681
# springer 2011   21425     128575  3239   431  1666.666667
#          2012   39197     282151  7836   441  3531.296703
# summer   2011   77564     269752  5805   795  3775.173913
#          2012  125958     445315  8362  1027  6209.489130
# winter   2011   52813     273324  5511   627  3664.460674
#          2012   76969     438507  8555    22  5791.865169

# %% [markdown]
# #### Memberi label pada workingday

# %%
day_df["workingday"]= day_df.workingday.apply(lambda x: "holiday/week end" if x == 0 else "working day")
day_df.sample()
# Out:
#      instant     dteday  season    yr  mnth  holiday weekday   workingday  \
# 468      469 2012-04-13  summer  2012     4        0  friday  working day
#
#                            weathersit    temp     atemp       hum  windspeed  \
# 468  clear, few clouds, partly cloudy  0.4425  0.431808  0.408333   0.155471
#
#      casual  registered   cnt
# 468    1252        5146  6398

# %% [markdown]
# #### Melihat penyeawaan sepeda pada hari libur pertahun

# %%
day_df.groupby(by = ["yr","workingday"]).agg({
    "casual" : "sum",
    "registered" : "sum",
    "cnt" : "sum"
})
# Out:
#                        casual  registered      cnt
# yr   workingday
# 2011 holiday/week end  128898      257941   386839
#      working day       118354      737910   856264
# 2012 holiday/week end  187834      425596   613430
#      working day       184931     1251215  1436146

# %% [markdown]
# **Insight tabel day_df:**
# - Penyewaan sepeda selama 2 tahun paling banyak terjadi pada musim gugur sebesar 1.061.129 penyewaan
# - Penyewaan sepeda selama 2 tahun pada weekday paling banyak terjadi pada hari Jum'at sebesar 487.790
# - Penyewaan sepeda casual sering terjadi pada musim gugur tahun 2012 sebanyak 130.641 penyewaan, sedangkan penyewaan registered paling banyak terjadi juga pada musim gugur tahun 2012 sebanyak 510.838 penyewaan
# - Penyewaan sepeda casual paling banyak terjadi pada holiday/weekend tahun 2012 sebanyak 187.834 penyewaa dan penyewaan registered paling banyak terjadi pada workingday tahun 2012 sebanyak 1.251.215 penyewaan

# %% [markdown]
# ### Eksplore tabel hour_df

# %% [markdown]
# #### Melihat statistik seluruh tabel hour_df

# %%
hour_df.describe(include="all")
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%        4.000000      6.000000      0.000000      1.000000      0.000000
# 50%        7.000000     12.000000      0.000000      3.000000      1.000000
# 75%       10.000000     18.000000      0.000000      5.000000      1.000000
# max       12.000000     23.000000      1.000000      6.000000      1.000000
# std        3.438776      6.914405      0.167165      2.005771      0.465431
#
#          weathersit          temp         atemp           hum     windspeed  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       1.425283      0.496987      0.475775      0.627229      0.190098
# min        1.000000      0.020000      0.000000      0.000000      0.000000
# 25%        1.000000      0.340000      0.333300      0.480000      0.104500
# 50%        1.000000      0.500000      0.484800      0.630000      0.194000
# 75%        2.000000      0.660000      0.621200      0.780000      0.253700
# max        4.000000      1.000000      1.000000      1.000000      0.850700
# std        0.639357      0.192556      0.171850      0.192930      0.122340
#
#              casual    registered           cnt
# count  17379.000000  17379.000000  17379.000000
# mean      35.676218    153.786869    189.463088
# min        0.000000      0.000000      1.000000
# 25%        4.000000     34.000000     40.000000
# 50%       17.000000    115.000000    142.000000
# 75%       48.000000    220.000000    281.000000
# max      367.000000    886.000000    977.000000
# std       49.305030    151.357286    181.387599

# %% [markdown]
# #### Memberikan label pada season

# %%
hour_df["season"]= hour_df.season.apply(lambda x: "springer" if x == 1 else ("summer" if x == 2 else ("fall" if x == 3 else "winter")))
hour_df.sample(10)
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 7422      7423 2011-11-10  winter   0    11  21        0        4           1
# 2267      2268 2011-04-09  summer   0     4   8        0        6           0
# 6226      6227 2011-09-22    fall   0     9   0        0        4           1
# 13371    13372 2012-07-16    fall   1     7   8        0        1           1
# 3949      3950 2011-06-18  summer   0     6  11        0        6           0
# 4900      4901 2011-07-28    fall   0     7   2        0        4           1
# 6478      6479 2011-10-02  winter   0    10  12        0        0           0
# 2006      2007 2011-03-29  summer   0     3  11        0        2           1
# 10830    10831 2012-04-01  summer   1     4   9        0        0           0
# 14307    14308 2012-08-24    fall   1     8   8        0        5           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 7422            1  0.36  0.3333  0.57     0.2537       6         130  136
# 2267            2  0.32  0.3030  0.93     0.1642       7          47   54
# 6226            1  0.60  0.5152  0.94     0.1045      11          30   41
# 13371           1  0.74  0.6970  0.66     0.1045      48         619  667
# 3949            1  0.72  0.6818  0.62     0.1343     134         270  404
# 4900            1  0.72  0.6667  0.54     0.1045       2           5    7
# 6478            2  0.40  0.4091  0.62     0.1940      78         243  321
# 2006            2  0.34  0.3030  0.25     0.3881      18          63   81
# 10830           2  0.36  0.3485  0.81     0.1343     102         173  275
# 14307           2  0.66  0.6212  0.74     0.0000      41         703  744

# %% [markdown]
# #### Memberikan label pada tahun

# %%
hour_df["yr"]= hour_df.yr.apply(lambda x: 2011 if x == 0 else 2012)
hour_df.sample()
# Out:
#       instant     dteday  season    yr  mnth  hr  holiday  weekday  \
# 1827     1828 2011-03-21  summer  2011     3  21        0        1
#
#       workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 1827           1           1  0.46  0.4545  0.94      0.194      12
#
#       registered  cnt
# 1827          79   91

# %% [markdown]
# #### Memberikan label pada weekday

# %%
hour_df["weekday"]= hour_df.weekday.apply(lambda x: "sunday" if x == 0 else ("monday" if x == 1 else ("tuesday" if x == 2 else ("wednesday" if x == 3 else ("thursday" if x == 4 else("friday" if x ==5 else "saturday"))))))
hour_df.head(5)
# Out:
#    instant     dteday    season    yr  mnth  hr  holiday   weekday  \
# 0        1 2011-01-01  springer  2011     1   0        0  saturday
# 1        2 2011-01-01  springer  2011     1   1        0  saturday
# 2        3 2011-01-01  springer  2011     1   2        0  saturday
# 3        4 2011-01-01  springer  2011     1   3        0  saturday
# 4        5 2011-01-01  springer  2011     1   4        0  saturday
#
#    workingday  weathersit  temp   atemp   hum  windspeed  casual  registered  \
# 0           0           1  0.24  0.2879  0.81        0.0       3          13
# 1           0           1  0.22  0.2727  0.80        0.0       8          32
# 2           0           1  0.22  0.2727  0.80        0.0       5          27
# 3           0           1  0.24  0.2879  0.75        0.0       3          10
# 4           0           1  0.24  0.2879  0.75        0.0       0           1
#
#    cnt
# 0   16
# 1   40
# 2   32
# 3   13
# 4    1

# %% [markdown]
# #### Memberikan label pada workingday

# %%
hour_df["workingday"]= hour_df.workingday.apply(lambda x: "holiday/week end" if x == 0 else "working day")
hour_df.sample()
# Out:
#       instant     dteday    season    yr  mnth  hr  holiday  weekday  \
# 9198     9199 2012-01-24  springer  2012     1   4        0  tuesday
#
#        workingday  weathersit  temp   atemp  hum  windspeed  casual  \
# 9198  working day           2   0.3  0.3182  1.0     0.0896       0
#
#       registered  cnt
# 9198           2    2

# %% [markdown]
# #### Memberikan label pada weathersit

# %%
hour_df["weathersit"]= hour_df.weathersit.apply(lambda x: "clear, few clouds, partly cloudy" if x == 1 else ("mist + cloudy, mist + broken, mist + few clouds" if x == 2 else ("light snow, light rain + thunderstorm + scatter clouds, light rain + scatter clouds" if x == 3 else "heavy rain + ice pallets + thunderstorm + mist, snow + fog")))
hour_df.head(5)
# Out:
#    instant     dteday    season    yr  mnth  hr  holiday   weekday  \
# 0        1 2011-01-01  springer  2011     1   0        0  saturday
# 1        2 2011-01-01  springer  2011     1   1        0  saturday
# 2        3 2011-01-01  springer  2011     1   2        0  saturday
# 3        4 2011-01-01  springer  2011     1   3        0  saturday
# 4        5 2011-01-01  springer  2011     1   4        0  saturday
#
#          workingday                        weathersit  temp   atemp   hum  \
# 0  holiday/week end  clear, few clouds, partly cloudy  0.24  0.2879  0.81
# 1  holiday/week end  clear, few clouds, partly cloudy  0.22  0.2727  0.80
# 2  holiday/week end  clear, few clouds, partly cloudy  0.22  0.2727  0.80
# 3  holiday/week end  clear, few clouds, partly cloudy  0.24  0.2879  0.75
# 4  holiday/week end  clear, few clouds, partly cloudy  0.24  0.2879  0.75
#
#    windspeed  casual  registered  cnt
# 0        0.0       3          13   16
# 1        0.0       8          32   40
# 2        0.0       5          27   32
# 3        0.0       3          10   13
# 4        0.0       0           1    1

# %% [markdown]
# #### Melihat waktu penyewaan sepeda pada workingday berdasarkan cnt

# %%
hour_df.groupby(by = ["workingday","hr"]).agg({
    "casual" : "sum",
    "registered": "sum",
    "cnt" : "sum"
}).sort_values(by = "cnt", ascending=False)
# Out:
#                      casual  registered     cnt
# workingday       hr
# working day      17   28391      233729  262120
#                  18   25125      220004  245129
#                  8    11043      225552  236595
#                  19   20429      153075  173504
#                  16   24124      122144  146268
#                  7     6049      138095  144144
#                  20   15622      108738  124360
#                  9    12059      107734  119793
#                  15   23074       77189  100263
#                  12   20555       79253   99808
#                  13   21199       77619   98818
#                  21   12256       80515   92771
#                  14   22843       68576   91419
# holiday/week end 13   31514       54587   86101
#                  12   29163       55443   84606
#                  14   32246       51987   84233
#                  15   31532       51354   82886
#                  16   29710       51770   81480
# working day      11   18649       59833   78482
# holiday/week end 17   25829       48911   74740
#                  11   24637       48201   72838
# working day      22    9747       59171   68918
#                  10   15478       51664   67142
# holiday/week end 18   19371       45272   64643
#                  10   18311       40804   59115
#                  19   15076       38209   53285
# working day      6     2142       48698   50840
#                  23    6663       37514   44177
# holiday/week end 20   10756       29434   40190
#                  9    10399       29246   39645
#                  21    8314       24360   32674
#                  22    6453       20241   26694
#                  8     4718       19688   24406
#                  0     3829       17055   20884
#                  23    4402       15362   19764
# working day      0     3546       14700   18246
# holiday/week end 1     2876       13111   15987
# working day      5      629       11703   12332
# holiday/week end 2     2371        9752   12123
#                  7     1988        8039   10027
# working day      1     1833        6344    8177
# holiday/week end 3     1465        4386    5851
#                  6      875        3417    4292
# working day      2     1041        3188    4229
#                  4      360        2192    2552
#                  3      428        1895    2323
# holiday/week end 5      383        1546    1929
#                  4      514        1362    1876

# %% [markdown]
# #### Melihat berapa lama penyewaan sepeda berdasarkan cuaca per tahun

# %%
hour_df.groupby(by = ["hr","weathersit"]).agg({
    "cnt" : "sum"
}).sort_values(by ="cnt", ascending=False).head(10)
# Out:
#                                         cnt
# hr weathersit
# 17 clear, few clouds, partly cloudy  253718
# 18 clear, few clouds, partly cloudy  229220
# 16 clear, few clouds, partly cloudy  171230
# 19 clear, few clouds, partly cloudy  171073
# 8  clear, few clouds, partly cloudy  158998
# 15 clear, few clouds, partly cloudy  133486
# 13 clear, few clouds, partly cloudy  131209
# 14 clear, few clouds, partly cloudy  127726
# 20 clear, few clouds, partly cloudy  127332
# 12 clear, few clouds, partly cloudy  124915

# %% [markdown]
# **Insight tabel hour_df:**
# - Penyewaan sepeda selama 2 tahun paling banyak terjadi pada workingday dari pukul 7 hingga pukul 21
# - Penyewaan sepeda selama 2 tahun paling banyak terjadi pada cuaca clear, few, clouds, partly cloudly dari pukul 8 hingga pukul 20

# %%
#mengelompokkan waktu dan membuat kolom baru
hour_df["time"]= hour_df.hr.apply(lambda x: "midnight" if x <5 else ("morning" if x<11 else ("midday" if x<15 else ("afternoon" if x<18 else ("evening")))))
hour_df
# Out:
#        instant     dteday    season    yr  mnth  hr  holiday   weekday  \
# 0            1 2011-01-01  springer  2011     1   0        0  saturday
# 1            2 2011-01-01  springer  2011     1   1        0  saturday
# 2            3 2011-01-01  springer  2011     1   2        0  saturday
# 3            4 2011-01-01  springer  2011     1   3        0  saturday
# 4            5 2011-01-01  springer  2011     1   4        0  saturday
# ...        ...        ...       ...   ...   ...  ..      ...       ...
# 17374    17375 2012-12-31  springer  2012    12  19        0    monday
# 17375    17376 2012-12-31  springer  2012    12  20        0    monday
# 17376    17377 2012-12-31  springer  2012    12  21        0    monday
# 17377    17378 2012-12-31  springer  2012    12  22        0    monday
# 17378    17379 2012-12-31  springer  2012    12  23        0    monday
#
#              workingday                                       weathersit  \
# 0      holiday/week end                 clear, few clouds, partly cloudy
# 1      holiday/week end                 clear, few clouds, partly cloudy
# 2      holiday/week end                 clear, few clouds, partly cloudy
# 3      holiday/week end                 clear, few clouds, partly cloudy
# 4      holiday/week end                 clear, few clouds, partly cloudy
# ...                 ...                                              ...
# 17374       working day  mist + cloudy, mist + broken, mist + few clouds
# 17375       working day  mist + cloudy, mist + broken, mist + few clouds
# 17376       working day                 clear, few clouds, partly cloudy
# 17377       working day                 clear, few clouds, partly cloudy
# 17378       working day                 clear, few clouds, partly cloudy
#
#        temp   atemp   hum  windspeed  casual  registered  cnt      time
# 0      0.24  0.2879  0.81     0.0000       3          13   16  midnight
# 1      0.22  0.2727  0.80     0.0000       8          32   40  midnight
# 2      0.22  0.2727  0.80     0.0000       5          27   32  midnight
# 3      0.24  0.2879  0.75     0.0000       3          10   13  midnight
# 4      0.24  0.2879  0.75     0.0000       0           1    1  midnight
# ...     ...     ...   ...        ...     ...         ...  ...       ...
# 17374  0.26  0.2576  0.60     0.1642      11         108  119   evening
# 17375  0.26  0.2576  0.60     0.1642       8          81   89   evening
# 17376  0.26  0.2576  0.60     0.1642       7          83   90   evening
# 17377  0.26  0.2727  0.56     0.1343      13          48   61   evening
# 17378  0.26  0.2727  0.65     0.1343      12          37   49   evening
#
# [17379 rows x 18 columns]

# %% [markdown]
# ### EDA menggabungkan tabel day df dan tabel hour df

# %%
maindata_df = pd.merge(
    left = hour_df,
    right = day_df,
    how = "left",
    left_on = "dteday",
    right_on = "dteday"
)
maindata_df.head()
# Out:
#    instant_x     dteday  season_x  yr_x  mnth_x  hr  holiday_x weekday_x  \
# 0          1 2011-01-01  springer  2011       1   0          0  saturday
# 1          2 2011-01-01  springer  2011       1   1          0  saturday
# 2          3 2011-01-01  springer  2011       1   2          0  saturday
# 3          4 2011-01-01  springer  2011       1   3          0  saturday
# 4          5 2011-01-01  springer  2011       1   4          0  saturday
#
#        workingday_x                      weathersit_x  ...  weekday_y  \
# 0  holiday/week end  clear, few clouds, partly cloudy  ...   saturday
# 1  holiday/week end  clear, few clouds, partly cloudy  ...   saturday
# 2  holiday/week end  clear, few clouds, partly cloudy  ...   saturday
# 3  holiday/week end  clear, few clouds, partly cloudy  ...   saturday
# 4  holiday/week end  clear, few clouds, partly cloudy  ...   saturday
#
#        workingday_y                                     weathersit_y  \
# 0  holiday/week end  mist + cloudy, mist + broken, mist + few clouds
# 1  holiday/week end  mist + cloudy, mist + broken, mist + few clouds
# 2  holiday/week end  mist + cloudy, mist + broken, mist + few clouds
# 3  holiday/week end  mist + cloudy, mist + broken, mist + few clouds
# 4  holiday/week end  mist + cloudy, mist + broken, mist + few clouds
#
#      temp_y   atemp_y     hum_y  windspeed_y casual_y  registered_y cnt_y
# 0  0.344167  0.363625  0.805833     0.160446      331           654   985
# 1  0.344167  0.363625  0.805833     0.160446      331           654   985
# 2  0.344167  0.363625  0.805833     0.160446      331           654   985
# 3  0.344167  0.363625  0.805833     0.160446      331           654   985
# 4  0.344167  0.363625  0.805833     0.160446      331           654   985
#
# [5 rows x 33 columns]

# %%
maindata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instant_x     17379 non-null  int64
#  1   dteday        17379 non-null  datetime64[ns]
#  2   season_x      17379 non-null  object
#  3   yr_x          17379 non-null  int64
#  4   mnth_x        17379 non-null  int64
#  5   hr            17379 non-null  int64
#  6   holiday_x     17379 non-null  int64
#  7   weekday_x     17379 non-null  object
#  8   workingday_x  17379 non-null  object
#  9   weathersit_x  17379 non-null  object
#  10  temp_x        17379 non-null  float64
#  11  atemp_x       17379 non-null  float64
#  12  hum_x         17379 non-null  float64
#  13  windspeed_x   17379 non-null  float64
#  14  casual_x      17379 non-null  int64
#  15  registered_x  17379 non-null  int64
#  16  cnt_x         17379 non-null  int64
#  17  time          17379 non-null  object
#  18  instant_y     17379 non-null  int64
#  19  season_y      17379 non-null  object
#  20  yr_y          17379 non-null  int64
#  21  mnth_y        17379 non-null  int64
#  22  holiday_y     17379 non-null  int64
#  23  weekday_y     17379 non-null  object
#  24  workingday_y  17379 non-null  object
#  25  weathersit_y  17379 non-null  object
#  26  temp_y        17379 non-null  float64
#  27  atemp_y       17379 non-null  float64
#  28  hum_y         17379 non-null  float64
#  29  windspeed_y   17379 non-null  float64
#  30  casual_y      17379 non-null  int64
#  31  registered_y  17379 non-null  int64
#  32  cnt_y         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(15), object(9)
# memory usage: 4.4+ MB

# %% [markdown]
# #### Membuat berkas maindata_df ke bentuk csv

# %%
#maindata_df.to_csv("main_data.csv", index=False)

# %% [markdown]
# #### Memanggil data main_data.csv

# %%
maindata_df = pd.read_csv("dashboard/main_data.csv")

# %%
maindata_df
# Out:
#        instant_x      dteday  season_x  yr_x  mnth_x  hr  holiday_x weekday_x  \
# 0              1  2011-01-01  springer  2011       1   0          0  saturday
# 1              2  2011-01-01  springer  2011       1   1          0  saturday
# 2              3  2011-01-01  springer  2011       1   2          0  saturday
# 3              4  2011-01-01  springer  2011       1   3          0  saturday
# 4              5  2011-01-01  springer  2011       1   4          0  saturday
# ...          ...         ...       ...   ...     ...  ..        ...       ...
# 17374      17375  2012-12-31  springer  2012      12  19          0    monday
# 17375      17376  2012-12-31  springer  2012      12  20          0    monday
# 17376      17377  2012-12-31  springer  2012      12  21          0    monday
# 17377      17378  2012-12-31  springer  2012      12  22          0    monday
# 17378      17379  2012-12-31  springer  2012      12  23          0    monday
#
#            workingday_x                                     weathersit_x  ...  \
# 0      holiday/week end                 clear, few clouds, partly cloudy  ...
# 1      holiday/week end                 clear, few clouds, partly cloudy  ...
# 2      holiday/week end                 clear, few clouds, partly cloudy  ...
# 3      holiday/week end                 clear, few clouds, partly cloudy  ...
# 4      holiday/week end                 clear, few clouds, partly cloudy  ...
# ...                 ...                                              ...  ...
# 17374       working day  mist + cloudy, mist + broken, mist + few clouds  ...
# 17375       working day  mist + cloudy, mist + broken, mist + few clouds  ...
# 17376       working day                 clear, few clouds, partly cloudy  ...
# 17377       working day                 clear, few clouds, partly cloudy  ...
# 17378       working day                 clear, few clouds, partly cloudy  ...
#
#        weekday_y      workingday_y  \
# 0       saturday  holiday/week end
# 1       saturday  holiday/week end
# 2       saturday  holiday/week end
# 3       saturday  holiday/week end
# 4       saturday  holiday/week end
# ...          ...               ...
# 17374     monday       working day
# 17375     monday       working day
# 17376     monday       working day
# 17377     monday       working day
# 17378     monday       working day
#
#                                           weathersit_y    temp_y   atemp_y  \
# 0      mist + cloudy, mist + broken, mist + few clouds  0.344167  0.363625
# 1      mist + cloudy, mist + broken, mist + few clouds  0.344167  0.363625
# 2      mist + cloudy, mist + broken, mist + few clouds  0.344167  0.363625
# 3      mist + cloudy, mist + broken, mist + few clouds  0.344167  0.363625
# 4      mist + cloudy, mist + broken, mist + few clouds  0.344167  0.363625
# ...                                                ...       ...       ...
# 17374  mist + cloudy, mist + broken, mist + few clouds  0.215833  0.223487
# 17375  mist + cloudy, mist + broken, mist + few clouds  0.215833  0.223487
# 17376  mist + cloudy, mist + broken, mist + few clouds  0.215833  0.223487
# 17377  mist + cloudy, mist + broken, mist + few clouds  0.215833  0.223487
# 17378  mist + cloudy, mist + broken, mist + few clouds  0.215833  0.223487
#
#           hum_y  windspeed_y casual_y  registered_y cnt_y
# 0      0.805833     0.160446      331           654   985
# 1      0.805833     0.160446      331           654   985
# 2      0.805833     0.160446      331           654   985
# 3      0.805833     0.160446      331           654   985
# 4      0.805833     0.160446      331           654   985
# ...         ...          ...      ...           ...   ...
# 17374  0.577500     0.154846      439          2290  2729
# 17375  0.577500     0.154846      439          2290  2729
# 17376  0.577500     0.154846      439          2290  2729
# 17377  0.577500     0.154846      439          2290  2729
# 17378  0.577500     0.154846      439          2290  2729
#
# [17379 rows x 33 columns]

# %%
maindata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instant_x     17379 non-null  int64
#  1   dteday        17379 non-null  object
#  2   season_x      17379 non-null  object
#  3   yr_x          17379 non-null  int64
#  4   mnth_x        17379 non-null  int64
#  5   hr            17379 non-null  int64
#  6   holiday_x     17379 non-null  int64
#  7   weekday_x     17379 non-null  object
#  8   workingday_x  17379 non-null  object
#  9   weathersit_x  17379 non-null  object
#  10  temp_x        17379 non-null  float64
#  11  atemp_x       17379 non-null  float64
#  12  hum_x         17379 non-null  float64
#  13  windspeed_x   17379 non-null  float64
#  14  casual_x      17379 non-null  int64
#  15  registered_x  17379 non-null  int64
#  16  cnt_x         17379 non-null  int64
#  17  time          17379 non-null  object
#  18  instant_y     17379 non-null  int64
#  19  season_y      17379 non-null  object
#  20  yr_y          17379 non-null  int64
#  21  mnth_y        17379 non-null  int64
#  22  holiday_y     17379 non-null  int64
#  23  weekday_y     17379 non-null  object
#  24  workingday_y  17379 non-null  object
#  25  weathersit_y  17379 non-null  object
#  26  temp_y        17379 non-null  float64
#  27  atemp_y       17379 non-null  float64
#  28  hum_y         17379 non-null  float64
#  29  windspeed_y   17379 non-null  float64
#  30  casual_y      17379 non-null  int64
#  31  registered_y  17379 non-null  int64
#  32  cnt_y         17379 non-null  int64
# dtypes: float64(8), int64(15), object(10)
# memory usage: 4.4+ MB

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
byseason_per_yr_df = maindata_df.groupby(by = ["season_x","yr_x"]).cnt_x.sum().reset_index()
byseason_per_yr_df.rename(columns={
    "cnt_x" : "sum"
}, inplace =True)

plt.figure(figsize=(10,5))

colors=["#73bca4", "#f8a4c7"]

sns.barplot(
    y ="sum",
    x = "season_x",
    hue = "yr_x",
    data =byseason_per_yr_df.sort_values(by ="sum", ascending=False),
    palette = colors                
)

plt.title("Visualisation Bike Sharing Based on Season per Year", loc='center', fontsize=15)
plt.ylabel("Summary")
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %%
byweekday_df = maindata_df.groupby(by ="weekday_x").cnt_x.sum().reset_index()
byweekday_df.rename(columns={
    "cnt_x" : "sum"
}, inplace =True)

plt.figure(figsize=(10,5))

colors=["#73bca4", "#f8a4c7", "#a57bdc", "#1facf7", "#2c6fda", "#e3bca4", "#d3d2d4"]
explode = (0.1, 0, 0, 0, 0, 0, 0)

plt.pie(
    x = byweekday_df['sum'],
    labels = byweekday_df['weekday_x'],
    autopct = '%1.2f%%',
    colors=colors,
    explode = explode,
    shadow=True,
    wedgeprops={'width':0.6}
)
plt.title("Bike Sharing Based on Using at Weekday", loc="center", fontsize=15)
plt.show()

# %%
#maindata_df['time'].describe(include='all')
#day_df.groupby(by = "weekday").cnt.sum().sort_values(ascending=False)
maindata_df.groupby(by='time').cnt_x.sum().sort_values(ascending=False)
# Out:
# time
# evening      986109
# morning      770260
# afternoon    747757
# midday       696305
# midnight      92248
# Name: cnt_x, dtype: int64

# %%
bytime_df = maindata_df.groupby(by ="time").cnt_x.sum().reset_index()
bytime_df.rename(columns={
    "cnt_x" : "sum"
}, inplace =True)

plt.figure(figsize=(10,5))

colors=["#73bca4", "#a57bdc", "#2c6fda", "#e3bca4", "#d3d2d4"]
explode =(0, 0.1, 0, 0,0)

plt.pie(
    x = bytime_df['sum'],
    labels = bytime_df['time'],
    autopct = '%1.2f%%',
    colors=colors,
    explode = explode,
    shadow=True,
    wedgeprops={'width':0.6}
)
plt.title("Bike Sharing Based on Using by Time", loc="center", fontsize=15)
plt.show()

# %%
byworkingday_per_yr_df = maindata_df.groupby(by = ["workingday_x","yr_x"]).cnt_x.sum().reset_index()
byworkingday_per_yr_df.rename(columns={
    "cnt_x" : "sum"
}, inplace =True)

plt.figure(figsize=(10,5))

colors=["#73bca4", "#2c6fda"]

sns.barplot(
    y ="sum",
    x = "workingday_x",
    hue = "yr_x",
    data =byworkingday_per_yr_df.sort_values(by ="sum", ascending=False),
    palette = colors,
)

plt.title("Visualisation Bike Sharing Based on Workingday per Year", loc='center', fontsize=15)
plt.ylabel("Summary")
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
byworkingday_per_hr_df = maindata_df.groupby(by = ["workingday_y","hr"]).cnt_y.sum().reset_index()
byworkingday_per_hr_df.rename(columns={
    "cnt_y" : "sum"
}, inplace =True)

plt.figure(figsize=(10,5))

colors=["#e3bca4", "#a57bdc"]

sns.barplot(
    y ="sum",
    x = "hr",
    hue = "workingday_y",
    data =byworkingday_per_hr_df.sort_values(by ="sum", ascending=False).sample(10),
    palette = colors                
)

plt.title("Visualisation Bike Sharing Based on Workingday per Hour", loc='center', fontsize=15)
plt.ylabel("Summary")
plt.xlabel("Hour")
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %%
byweathersit_per_hr_df= maindata_df.groupby(by = ["weathersit_y", "hr"]).cnt_y.sum().reset_index()
byweathersit_per_hr_df.rename(columns={
    "cnt_y" : "sum"
}, inplace=True)

plt.figure(figsize=(10,5))

colors=["#e3bca4", "#a57bdc", "#f8a4c7", "#2c6fda" ]

sns.barplot(
    y ="sum",
    x = "hr",
    hue = "weathersit_y",
    data =byweathersit_per_hr_df.sort_values(by ="sum", ascending=False).sample(10),
    palette = colors                
)

plt.title("Visualisation Bike Sharing Based on Weathersit per Hour", loc='center', fontsize=15)
plt.ylabel("Summary")
plt.xlabel("Hour")
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# **Insight:**
# - Dari visualisasi dapat dilihat penyewaan sepeda meningkat pada tahun 2012
# - Penyewaan sepeda jika dilihat berdasarkan musim, maka akan meningkat pada musim gugur
# - Penyewaan sepeda paling sering terjadi dihari Jum'at
# - Penyewaan sepeda sering dilakukan pada cuaca cerah berawan
# - Penyewaan sepeda sering terjadi pada hari kerja bukan pada hari libur

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# **Clusterring**
# - Mengelompokkan jam penyewaan sepeda terbanyak per tahun
# - Mengelompokkan penyewaan sepeda berdasarkan tipe (casual atau registered) per musim

# %%
# Mengelompokkan jam penyewaan sepeda per tahun
clustime_df = maindata_df.groupby(by=["yr_y", "hr"]).agg({
    "cnt_x" : "sum"
}).sort_values(by = "cnt_x", ascending=False)


clustime_df.head(10)
# Out:
#           cnt_x
# yr_y hr
# 2012 17  209228
#      18  192787
#      8   165534
#      16  142126
#      19  140987
# 2011 17  127632
#      18  116985
# 2012 13  115580
#      12  115216
#      15  114559

# %%
# Mengelompokkan jenis penyewaan sepeda per musim
clusseason_df = maindata_df.groupby(by="season_x").agg({
    "casual_x" : "sum",
    "registered_x" : "sum"
}).sort_values(by = ["casual_x"] + ["registered_x"], ascending=False)


clusseason_df.head(10)
# Out:
#           casual_x  registered_x
# season_x
# fall        226091        835038
# summer      203522        715067
# winter      129782        711831
# springer     60622        410726

# %% [markdown]
# ### Visual Clusterring

# %%
byclustime_df= maindata_df.groupby(by = ["yr_y", "hr"]).cnt_x.sum().reset_index()
byclustime_df.rename(columns={
    "cnt_x" : "sum"
}, inplace=True)

plt.figure(figsize=(10,5))

colors=["#e3bca4", "#a57bdc", "#f8a4c7"]

sns.barplot(
    y ="sum",
    x = "hr",
    hue="yr_y",
    data =byclustime_df.sort_values(by ="sum", ascending=False).head(10),
    palette = colors                
)

plt.title("Visualisation Time Clusterring per Hour", loc='center', fontsize=15)
plt.ylabel("Summary")
plt.xlabel("Hour")
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %%
byclusseason_df= maindata_df.groupby(by = "season_x").casual_x.sum().reset_index()
byclusseason_df.rename(columns={
    "casual_x" : "sum",
}, inplace=True)

byclusseason1_df= maindata_df.groupby(by = "season_x").registered_x.sum().reset_index()
byclusseason1_df.rename(columns={
    "registered_x" : "sum",
}, inplace=True)

fig, ax= plt.subplots(nrows=1, ncols=2, figsize=(30, 6))

colors=["#e3bca4", "#a57bdc", "#f8a4c7", "#2c6fda"]

sns.barplot(
    y ="sum",
    x = "season_x",
    #hue="yr_y",
    data =byclusseason_df.sort_values(by ="sum", ascending=False).head(10),
    palette = colors,
    ax=ax[0]
)

ax[0].set_title("Visualisation Time Clusterring on Season", loc='center', fontsize=15)
ax[0].set_ylabel("Summary")
ax[0].set_xlabel("Season")
ax[0].tick_params(axis='x', labelsize=12)

sns.barplot(
    y ="sum",
    x = "season_x",
    #hue="yr_y",
    data =byclusseason1_df.sort_values(by ="sum", ascending=False).head(10),
    palette = colors,
    ax=ax[1]
)

ax[1].set_title("Visualisation Registered on Season", loc="center", fontsize=18)
ax[1].set_ylabel("Summary")
ax[1].set_xlabel("Season")
ax[1].tick_params(axis='x', labelsize=12)

plt.suptitle("Clusstering Bike Sharing Based on Casual or Registered on Season", fontsize=20)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Penyewaan sepeda tiap tahun meningkat baik dilihat dari segi musim yang selalu ramai terjadi penyewaan pada musim gugur yang mencapai >600.000 kejadian dan terjadi peningkatan setiap tahun, ataupun hari kerja atau libur terlihat bahwa penyewaan sepeda sering terjadi pada hari kerja yang menyentuh angka >1,4 kejadian dan terjadi peningkatan setiap tahun, dan selama rentang waktu dua tahun penyewaan sepeda sering terjadi dihari jum'at dengan presentase sebesar 14,81%  hal ini baik untuk melatih masyarakat dalam kegiatan menjaga bumi agar bebas polusi. Sehingga perlu di galakkan kembali iklan untuk terus menggunakan sepeda dalam berkegiatan
# - Penyewaan sepeda yang dilihat dari beberapa sample data yang muncul pada hari kerja atau libur, sering terjadi dihari kerja pada pukul 3, pukul 7, pukul 12 hingga pukul 14, dan pukul 21 hingga pukul 22. Sedangkan penyewaan sepeda yang dilihat dari beberapa sample yang muncul berdasarkan cuaca, sering terjadi pada cuaca cerah, sedikit berawan, dan berawan pada pukul 5, pukul 17, pukul 20. Sedangkan pada clustering per waktu, penyewaan sepeda sering terjadi pada pukul 8, pukul 12, pukul 13, pukul 15 hingga pukul 19 yang terjadi pada periode 2011 dan 2012. Sehingga bisa ditarik kesimpulan penyewaan sepeda kemungkinan besar akan sering terjadi bila cuaca cerah pada hari kerja dari pukul 8 hingga pukul 20 sehingga dapat diantisipasi untuk ketersediaan sepeda pada kategori yang mendukung.
